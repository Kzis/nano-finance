# %% [markdown]
# <a href="https://colab.research.google.com/github/Kzis/big-data/blob/master/web_scape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import re
import lxml
from lxml.html.clean import Cleaner

# %%
def get_content(url):
    try:
        page = requests.get(url)
        soup = BeautifulSoup(page.content, 'html.parser')
    except:
        soup = None
    return soup

# %%
def clean_tag(msg):
    #remove html tag
    Tag_clean = re.compile(r'<[^>]+>')
    msg = Tag_clean.sub('', msg)
    #remove # and  “ , ”
    msg = re.sub(r'#|"|"', '', msg)
    #remove separator (\n, \t)
    msg = ''.join(msg.split())
    #remove numeric
    #msg = ''.join([i for i in msg if not i.isdigit()])
    return msg

# %%
def clean_cs_js(url):
    soup = get_content(url)
    if soup is not None:
        # remove all javascript and stylesheet code
        for script in soup(["script", "style"]):
            script.extract()
        text = soup.get_text()
        lines = (line.strip() for line in text.splitlines())
        # break multi-headlines into a line each
        chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
        #drop blank lines
        text = ' '.join(chunk for chunk in chunks if chunk)
    else:
        text = 'can not read this page'
    return text

# %%
url = "https://www.thairath.co.th/news/politic/1647081"
raw_content = get_content(url)
#content_no_html = clean_html(raw_content)
content_cleaned = clean_cs_js(url)

print(content_cleaned)
# Out:
# “ประยุทธ์” ปีติ ซาบซึ้งในพระมหากรุณาธิคุณ รัชกาลที่ 10 พระราชทานกำลังใจข่าวพระราชสำนักทั่วไทยเศรษฐกิจต่างประเทศการเมืองสังคมอาชญากรรมยานยนต์ไอทีหนังสือพิมพ์ไทยรัฐทีวีดูย้อนหลังผังรายการMost WatchedรายการแนะนำLiveไลฟ์สไตล์บ้านอาหารท่องเที่ยวไลฟ์MIRRORกีฬาฟุตบอลไทยฟุตบอลยุโรปไทยลีกฟุตซอลมวย/MMAวอลเลย์บอลE-Sportกีฬาอื่นๆไทยรัฐเชียร์ไทยแลนด์บันเทิงดวงหวยนิยายคลิปข่าวกิจกรรมโปรโมชั่นLiveข่าวพระราชสำนักทั่วไทยเศรษฐกิจต่างประเทศการเมืองสังคมอาชญากรรมยานยนต์ไอทีกีฬาฟุตบอลไทยฟุตบอลยุโรปไทยลีกฟุตซอลมวย/MMAวอลเลย์บอลE-Sportกีฬาอื่นๆไทยรัฐเชียร์ไทยแลนด์ไทยรัฐทีวีดูย้อนหลังผังรายการMost WatchedรายการแนะนำLiveไลฟ์สไตล์บ้านอาหารท่องเที่ยวไลฟ์หนังสือพิมพ์MIRRORบันเทิงดวงหวยนิยายคลิปข่าวกิจกรรมโปรโมชั่นThairath Talkข่าวพระราชสำนักทั่วไทยเศรษฐกิจต่างประเทศการเมืองสังคมอาชญากรรมยานยนต์ไอทีกีฬาฟุตบอลไทยฟุตบอลยุโรปไทยลีกฟุตซอลมวย/MMAวอลเลย์บอลE-Sportกีฬาอื่นๆไทยรัฐเชียร์ไทยแลนด์ไทยรัฐทีวีดูย้อนหลังผังรายการMost WatchedรายการแนะนำLiveไลฟ์สไตล์บ้านอาหารท่องเที่ยวไลฟ์หนังสือพิมพ์MIRRORบันเทิงดวงหวยนิยายคลิปข่าวกิจกรรมโปรโมชั่นThairath Talkข่าวพระราชสำนักทั่วไทยเศรษฐกิจต่างประเทศการเมืองสังคมอาชญากรรมยานยนต์ไอทีกีฬาฟุตบอลไทยฟุตบอลยุโรปไทยลีกฟุตซอลมวย/MMAวอลเลย์บอลE-Sportกีฬาอื่นๆไทยรัฐเชียร์ไทยแลนด์ไทยรัฐทีวีดูย้อนหลังผังรายการMost WatchedรายการแนะนำLiveไลฟ์สไตล์บ้านอาหารท่องเที่ยวไลฟ์หนังสือพิมพ์MIRRORบันเทิงดวงหวยนิยายคลิปข่าวกิจกรรมโปรโมชั่น100 ปี ชาตกาลกำพล วัชรพลร่วมงานกับเราเกี่ยวกับเราติดต่อเราFacebookTwitterInstagramYoutube“ประยุทธ์” ปีติ ซาบซึ้งในพระมหากรุณาธิคุณ รัชกาลที่ 10 พระราชทานกำลังใจข่าวการเมืองไทยรัฐออนไลน์27 ส.ค. 2562 15:34 น.SHARE “พล.อ.ประยุทธ์” อัญเชิญพระราชดำรัส ในหลวงรัชกาลที่ 10 พระราชทานกำลังใจ บอก ถือเป็นความภาคภูมิใจอันหาที่สุดมิได้ นั่งแถลงร่วมทีมโฆษก ย้ำ ครม.ทุกคนทำงานไม่แบ่งฝ่ายวันที่ 27 ส.ค. 2562 ผู้สื่อข่าวรายงานว่า ระหว่างการแถลงข่าวของทีมโฆษกรัฐบาล พล.อ.ประยุทธ์ จันทร์โอชา นายกรัฐมนตรี และรัฐมนตรีว่าการกระทรวงกลาโหม อัญเชิญพระราชดำรัส พระบาทสมเด็จพระปรเมนทรรามาธิบดีศรีสินทรมหาวชิราลงกรณ พระวชิรเกล้าเจ้าอยู่หัว ที่ทรงพระกรุณาโปรดเกล้าโปรดกระหม่อมพระราชทานให้นายกรัฐมนตรีและคณะรัฐมนตรีในวันนี้ พร้อมกล่าวว่า นี่ถือเป็นความภาคภูมิใจอันหาที่สุดมิได้ โดยเป็นพระราชดำรัสเมื่อวันที่ 16 ก.ค. 2562 ที่นายกรัฐมนตรีและ ครม. เข้าเฝ้าทูลละอองธุลีพระบาทถวายสัตย์ปฏิญาณตน ความว่า“ขอถือโอกาสนี้ ให้พรให้ท่านมีกำลังใจ ความมั่นใจ และความมุ่งมั่นที่จะปฏิบัติหน้าที่ เพื่อให้ได้ตามคำถวายสัตย์ปฏิญาณ ทั้งนี้ เพื่อประโยชน์สุขและความมั่นคงของประเทศชาติและประชาชน งานใดๆ ก็ต้องมีอุปสรรค งานใดๆ ก็ต้องมีปัญหา เพราะฉะนั้นก็เป็นเรื่องธรรมดาที่จะต้องแก้ปัญหา และเข้าหางาน เพื่อให้การบริหารประเทศ เป็นไปด้วยความเรียบร้อยตามสถานการณ์ โดยแก้ไขให้ตรงเป้าตรงจุด และมีความเข้มแข็งอดทนก็ขอให้คณะรัฐมนตรีและรัฐบาลได้มีกำลังใจ มีพลังที่จะปฏิบัติหน้าที่ด้วยดี ด้วยความถูกต้องต่อไป” ทั้งนี้ หลังพิธีรับพระราชทานพระราชดำรัสพร้อมลายพระราชหัตถ์ พล.อ.ประยุทธ์ กล่าวว่า ปัญหาทุกอย่างจะจบหรือไม่ ไม่อาจจะกล่าวได้ว่าเรื่องอื่นจะจบได้หรือไม่ แต่พระราชดำรัสที่ได้รับพระราชทานมาในวันนี้ ตนและคณะรัฐมนตรี ซาบซึ้งในพระมหากรุณาธิคุณ ซึ่งเป็นเรื่องที่ตนได้ทำเรื่องขอพระราชทานพระราชอนุญาตไป และทรงพระกรุณาโปรดเกล้าโปรดกระหม่อมเป็นลายลักษณ์อักษรมาให้คณะรัฐมนตรี และทุกคนจะน้อมนำเอาไปปฏิบัติ และนำพรดังกล่าวใส่กรอบประดับไว้ที่ทำงาน หรือที่อื่นๆ แล้วแต่ความสมควร ส่วนตนเองจะนำไปประดับไว้ที่ห้องทำงานขณะที่ก่อนหน้านี้มีพระราชดำรัสเผยแพร่ทางสื่อโทรทัศน์และสื่อโซเชียล แต่วันนี้ได้มีเอกสารที่เป็นลายลักษณ์อักษร ที่ให้ทุกคนได้เห็น ส่วนเรื่องอื่นก็ปล่อยให้เป็นเรื่องอื่นว่า ครม. จะต้องกล่าวคำถวายสัตย์ปฏิญาณต่อหรือไม่ ไม่ขอตอบ เพราะมีเรื่องงบประมาณรออยู่ ซึ่งก็ตอบได้อยู่แล้วจากนั้นได้เดินขึ้นไปแย่งเก้าอี้โฆษกรัฐบาล พร้อมหยอกล้อว่าสวยขึ้น ดูแจ่มใส และขอนั่งแถลงร่วมกับโฆษกเพื่อเป็นเกียรติ โดยระบุว่า ทีมโฆษกรัฐบาลทำงานร่วมกัน ไม่ว่าจะมาจากพรรคไหนก็ตามเพื่อเป็นรัฐบาลของแผ่นดินนี้ ดูแลประเทศชาติและประชาชนไปด้วยกัน ไม่มีความขัดแย้งอะไรทั้งสิ้น และหลายเรื่องที่ส่งมาจากกระทรวงต่างๆ สุดท้ายก็ต้องออกมาเป็นมติคณะรัฐมนตรีร่วมกัน ไม่ใช่ว่าผลงานของคนนี้อนุมัติให้และผลงานของคนโน้นไม่ได้อนุมัติให้ แต่ส่วนตัวเป็นคนกลาง ต้องให้ความเป็นธรรม เพราะทุกคนต่างทำเพื่อประชาชนทั้งสิ้น และทุกพรรคการเมืองที่ไปลงพื้นที่ก็ต่างรับรู้ปัญห ...
